# %%
# Definition for a binary tree node.
class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right
def invertTree(root):
        if not root:
            return
        # swap the children
        temp = root.left
        root.left = root.right
        root.right = temp
        # recursion on left subtree
        invertTree(root.left)
        # recursion on right subtree
        invertTree(root.right)

# Create a root node
root = TreeNode(4)

# Create the left child of the root node
root.left = TreeNode(2)

# Create the right child of the root node
root.right = TreeNode(7)

# Create the left child of the left child of the root node
root.left.left = TreeNode(1)

# Create the right child of the left child of the root node
root.left.right = TreeNode(3)

# Create the left child of the right child of the root node
root.right.left = TreeNode(6)

# Create the right child of the right child of the root node
root.right.right = TreeNode(9)

def print_tree(node):
  if node is None:
    return
  print_tree(node.left)
  print(node.val, end = " ")
  print_tree(node.right)

print_tree(root)

invertTree(root)

print("\n")
print_tree(root)
# Out:
# 1 2 3 4 6 7 9
#
# 9 7 6 4 3 2 1

# %%
# https://leetcode.com/problems/maximum-depth-of-binary-tree/
# 104. Maximum Depth of Binary Tree
# Definition for a binary tree node.
# class TreeNode:
#     def __init__(self, val=0, left=None, right=None):
#         self.val = val
#         self.left = left
#         self.right = right
class Solution:
    def maxDepth(self, root: Optional[TreeNode]) -> int:
        # approach one
         # dfs
        # if not root:
        #     return 0
        # return 1 + max(self.maxDepth(root.left), self.maxDepth(root.right))


        # BFS iterative
         # level by level
        print("initial:-" + root)
        if not root:
             return 0
        level = 0
        # inittalize q with root node
        q = deque([root])
        # run until q will be empty
        while q:
            # iterate throught the queue
            for i in range(len(q)):
                # pop the current element
                node = q.popleft()
                # add its left and right to list if present
                if node.left:
                    q.append(node.left)
                if node.right:
                    q.append(node.right)
            # increment level after going through the length , it marks as complete the current level
            level+=1
        # return level
        return level
        # create q with 3 as node, q has length
        # go through the length of q, pop 3 first and then add left 9 nd right 20 to the queue
        # now the queue has 9,20, so while loop,  go through the length, pop 9 first, add 0 as no children
        # then pop 20, add chilldren 15,7



        # # iterative DFS
        # # initialize stack with root node and depth as 1
        # stack =[[root, 1]]
        # res = 0
        # # untill the stack is empty
        # while stack:
        #     # pop the top
        #     node, depth = stack.pop()
        #     # this will take care if the left or right is either null
        #     if node:
        #         # res is max of previous depth and current popped depth
        #         res = max(res, depth)
        #         # append the children even if null
        #         stack.append([node.left, depth+1])
        #         stack.append([node.right, depth+1])
        # # return the result
        # return res
        # first the que contains 3,1
        # queue has some value, then entering the while loop
        # pop 3, we get 3 and 1 as depth,.... then add 3 children
        # 3 left is 9, append it with depth +1... 3 right is 20, append it same way
        # now next while loop with queue, 9, 20..... pop 20, add left and right.... pop 9, 9 has no children.. if node: takes care of it
# o(n) o(1)

root = [1,null,2]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-44b9fe7356fa> in <cell line: 9>()
#       7 #         self.left = left
#       8 #         self.right = right
# ----> 9 class Solution:
#      10     def maxDepth(self, root: Optional[TreeNode]) -> int:
#      11         # approach one
#
# <ipython-input-3-44b9fe7356fa> in Solution()
#       8 #         self.right = right
#       9 class Solution:
# ---> 10     def maxDepth(self, root: Optional[TreeNode]) -> int:
#      11         # approach one
#      12          # dfs
#
# NameError: name 'Optional' is not defined

# %%
# https://leetcode.com/problems/diameter-of-binary-tree/
# 543. Diameter of Binary Tree
# Definition for a binary tree node.
# Definition for a binary tree node.
# class TreeNode:
#     def __init__(self, val=0, left=None, right=None):
#         self.val = val
#         self.left = left
#         self.right = right
class Solution:
    def diameterOfBinaryTree(self, root: Optional[TreeNode]) -> int:
      # we do here list instead of int as the int is immutable and passed by values
      #  while list is passed by reference, so we use list =[0]
      # address is passed which defines where the value is stored
        res = [0]

        def dfs(root):
            if not root:
                # return -1 as 1-1 will be zero which is requirement
                return -1
            # same as recursive DFS logic
            left = dfs(root.left)
            right = dfs(root.right)
            # adding 2 to add two edges and then left and right height
            res[0] = max(res[0], 2+left+right)

            return 1+ max(left, right)

        dfs(root)
        return res[0]
# o(n) o(1)
root = [1,2,3,4,5]

# %%
# https://leetcode.com/problems/balanced-binary-tree/description/
# 110. Balanced Binary Tree

# EASY



# Definition for a binary tree node.
# class TreeNode:
#     def __init__(self, val=0, left=None, right=None):
#         self.val = val
#         self.left = left
#         self.right = right
class Solution:
    def isBalanced(self, root: Optional[TreeNode]) -> bool:
        def dfs(root):
            # if there is no node, return True and 0 as height
            # True because if there is no left or right, it is also balanced as difference between left and right will be zero
            if not root: return [True, 0]
            # dfs for left and right subtree recursively
            left, right = dfs(root.left), dfs(root.right)
            # balanced if. left and right is balanced and also difference is atmost one
            balanced = (left[0] and right[0]) and (abs(left[1] - right[1]) <=1 )
            # return balanced , 1 plus current depth
            return [balanced, 1+ max(left[1], right[1])]
        # return the result of balanced variable
        return dfs(root)[0]


root = [3,9,20,null,null,15,7]
isBalanced(root)

# %%
# https://leetcode.com/problems/same-tree/description/
# 100. Same Tree

# EASY


# Definition for a binary tree node.
# class TreeNode:
#     def __init__(self, val=0, left=None, right=None):
#         self.val = val
#         self.left = left
#         self.right = right
class Solution:
    def isSameTree(self, p: Optional[TreeNode], q: Optional[TreeNode]) -> bool:
        # if both the trees are empty, they are same, return true
        if not p and not q:
            return True
        # either of one of the tree is empty or value does not match, then return False
        if not p or not q or p.val!=q.val:
            return False
        # dfs recursively to left and right subtree
        # return if left and right are identical
        return (self.isSameTree(p.left, q.left) and
        self.isSameTree(p.right, q.right))

p = [1,2,3]
q = [1,2,3]

# %%
# https://leetcode.com/problems/subtree-of-another-tree/description/
# 572. Subtree of Another Tree

#EASY



# Definition for a binary tree node.
# class TreeNode:
#     def __init__(self, val=0, left=None, right=None):
#         self.val = val
#         self.left = left
#         self.right = right
class Solution:
    def isSubtree(self, root: Optional[TreeNode], subRoot: Optional[TreeNode]) -> bool:
        # is subroot is none, none is always a subtree of a tree
        if not subRoot: return True
        # if root is none, subroot cannot be its subtree
        if not root: return False
        # check if the trees are tje same
        if self.isSameTree(root, subRoot):
            return True
        # finally return recursively calling it on the left and right subtree
        return (self.isSubtree(root.left, subRoot) or
        self.isSubtree(root.right, subRoot))


    def isSameTree(self,p,q):
    # if both the trees are empty, they are same, return true
        if not p and not q:
            return True
        # check if there are trees and values at that node is equal
        if p and q and p.val==q.val:
        # dfs recursively to left and right subtree
        # return if left and right are identical
            return (self.isSameTree(p.left, q.left) and
            self.isSameTree(p.right, q.right))
        return False

#o(s.k) o(1)
root = [3,4,5,1,2], subRoot = [4,1,2]

# %%
# https://leetcode.com/problems/lowest-common-ancestor-of-a-binary-search-tree/
#235. Lowest Common Ancestor of a Binary Search Tree

# MEDIUM

# Definition for a binary tree node.
# class TreeNode:
#     def __init__(self, x):
#         self.val = x
#         self.left = None
#         self.right = None

class Solution:
    def lowestCommonAncestor(self, root: 'TreeNode', p: 'TreeNode', q: 'TreeNode') -> 'TreeNode':
        # set curr to root
        curr = root
        while curr:
            # if both the values are less
            if p.val<curr.val and q.val<curr.val:
                curr = curr.left
            # if both the values are greater
            elif p.val>curr.val and q.val>curr.val:
                curr = curr.right
            # if p is equal or
            #q is equal or
            #p is greater and q is  smaller
            else:
                return curr


# o(logn) o(1)
root = [6,2,8,0,4,7,9,null,null,3,5], p = 2, q = 8

# %%
# https://leetcode.com/problems/binary-tree-level-order-traversal/description/
# 102. Binary Tree Level Order Traversal
# MEDIUM
import collections

# Definition for a binary tree node.
# class TreeNode:
#     def __init__(self, val=0, left=None, right=None):
#         self.val = val
#         self.left = left
#         self.right = right
class Solution:
    def levelOrder(self, root: Optional[TreeNode]) -> List[List[int]]:

        # BFS iterative
        # level by level
        res = []
        # inittalize q with root node
        q = collections.deque()
        q.append(root)
        # run until q will be empty
        while q:
            lst = []
            print(lst)
            # iterate throught the queue
            for i in range(len(q)):
                # pop the current element
                node = q.popleft()
                # add if node and its left and right to list if present
                if node:
                    lst.append(node.val)
                    q.append(node.left)
                    q.append(node.right)
            # if there is no node, avoid adding empty list
            if lst:
                res.append(lst)
        return res

# o(n) o(1)

# %%
# https://leetcode.com/problems/binary-tree-right-side-view/description/
# 199. Binary Tree Right Side View
# MEDIUM


# Definition for a binary tree node.
# class TreeNode:
#     def __init__(self, val=0, left=None, right=None):
#         self.val = val
#         self.left = left
#         self.right = right
class Solution:
    def rightSideView(self, root: Optional[TreeNode]) -> List[int]:
        # BFS iterative
        # level by level
        res = []
        # inittalize q with root node
        q = collections.deque()
        q.append(root)
        # run until q will be empty
        while q:
          # variable to store the irght side
            rightSide = ''
            # iterate throught the queue
            for i in range(len(q)):
                # pop the current element
                node = q.popleft()
                # add if node and its left and right to list if present
                if node:
                    rightSide = node.val
                    q.append(node.left)
                    q.append(node.right)
              # we have the  rightmost node in the rightSide after the for loop
            # if there is no value, avoid adding empty list

            if rightSide!='':
                res.append(rightSide)
        return res

# o(n) o(1)

# %%
# https://leetcode.com/problems/count-good-nodes-in-binary-tree/submissions/
# 1448. Count Good Nodes in Binary Tree
# Definition for a binary tree node.
# class TreeNode:
#     def __init__(self, val=0, left=None, right=None):
#         self.val = val
#         self.left = left
#         self.right = right
class Solution:
    def goodNodes(self, root: TreeNode) -> int:
        def dfs(node, maxValue):
            if not node:
                return 0
            # if the the value is greater than max value
            res = 1 if node.val >= maxValue else 0
            # update the max value with the cirrent value
            maxValue = max(maxValue, node.val)
            # find res for left and right nodes
            res+= dfs(node.left, maxValue)
            res+= dfs(node.right, maxValue)
            # return result
            return res

        return dfs(root, root.val)
#  o(n) o(h)
root = [3,1,4,3,null,1,5]

# %%
# https://leetcode.com/problems/validate-binary-search-tree/
# 98. Validate Binary Search Tree
# https://leetcode.com/problems/validate-binary-search-tree/submissions/

# MEDIUM

# Definition for a binary tree node.
# class TreeNode:
#     def __init__(self, val=0, left=None, right=None):
#         self.val = val
#         self.left = left
#         self.right = right
class Solution:
    def isValidBST(self, root: Optional[TreeNode]) -> bool:
        def valid(node, left, right):
            if not node:
                return True
            # if value is greater than higher and less than lower
            if not(node.val < right and node.val > left):
                return False
            # while going to left, update the right boundry
            return (valid(node.left, left, node.val) and
            # while going to right, upate the left boundry
            valid(node.right, node.val, right))
        # initialize the boundries to infinity
        return valid(root, float("-inf"), float("infinity"))

# o(n) o(logn or h) height of the tree is h

root = [2,1,3]

# %%
# https://leetcode.com/problems/kth-smallest-element-in-a-bst/
# 230. Kth Smallest Element in a BST

class Solution:
    def kthSmallest(self, root: Optional[TreeNode], k: int) -> int:
        n = 0
        # stack to maintain the increasing order
        stack = []
        # check if the curr note or stack is empty
        while cur and stack:
            # keep moving to the left until null is found
            while cur:
                stack.append(cur)
                cur = cur.left
            # pop the node before null, visit that node
            cur = stack.pop()
            # increment the k
            n+=1
            # if n === k return the cur value
            if n == k:
                return cur.val
            # now we visited the root node basically, now visit the right node
            cur = cur.right
# o(n) o(1)

# %%
# https://leetcode.com/problems/construct-binary-tree-from-preorder-and-inorder-traversal/submissions/
# 105. Construct Binary Tree from Preorder and Inorder Traversal



# Definition for a binary tree node.
# class TreeNode:
#     def __init__(self, val=0, left=None, right=None):
#         self.val = val
#         self.left = left
#         self.right = right


# first value in pre order is always root
# use that value to find two subarrays in the inorder array. basically root in the inorder will have val;ues to its left and right
# get the count of these left and right values
# then recursively send that number of left portion in tha array and right in the pre ordere traversal to do th same thing
class Solution:
    def buildTree(self, preorder: List[int], inorder: List[int]) -> Optional[TreeNode]:
        if not preorder or not inorder:
            return None
        # first node is root
        root = TreeNode(preorder[0])
        # get index of mid in inorder
        mid = inorder.index(preorder[0])
        # recursive for left and right
        root.left = self.buildTree(preorder[1: mid+1], inorder[:mid])
        root.right = self.buildTree(preorder[mid+1 :], inorder[mid +1:])
        return root



preorder = [3,9,20,15,7]
inorder = [9,3,15,20,7]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-ed0adab72dd1> in <cell line: 16>()
#      14 # get the count of these left and right values
#      15 # then recursively send that number of left portion in tha array and right in the pre ordere traversal to do th same thing
# ---> 16 class Solution:
#      17     def buildTree(self, preorder: List[int], inorder: List[int]) -> Optional[TreeNode]:
#      18         if not preorder or not inorder:
#
# <ipython-input-1-ed0adab72dd1> in Solution()
#      15 # then recursively send that number of left portion in tha array and right in the pre ordere traversal to do th same thing
#      16 class Solution:
# ---> 17     def buildTree(self, preorder: List[int], inorder: List[int]) -> Optional[TreeNode]:
#      18         if not preorder or not inorder:
#      19             return None
#
# ...

# %%
# https://leetcode.com/problems/binary-tree-maximum-path-sum/
# 124. Binary Tree Maximum Path Sum
# Definition for a binary tree node.


# HARD
# class TreeNode:
#     def __init__(self, val=0, left=None, right=None):
#         self.val = val
#         self.left = left
#         self.right = right
class Solution:
    def maxPathSum(self, root: Optional[TreeNode]) -> int:
        res = [root.val]

        def dfs(root):
            if not root:
                return 0
            leftMax = dfs(root.left)
            rightMax = dfs(root.right)
            leftMax = max(leftMax, 0)
            rightMax = max(rightMax, 0)

            # compute max path with split
            res[0] = max(res[0], root.val + leftMax + rightMax)

            return root.val + max( leftMax, rightMax)

        dfs(root)
        return res[0]




        # o(n) o(h or logn )

# %%
# https://leetcode.com/problems/serialize-and-deserialize-binary-tree/
# 297. Serialize and Deserialize Binary Tree



# Definition for a binary tree node.
class TreeNode(object):
    def __init__(self, x):
        self.val = x
        self.left = None
        self.right = None

class Codec:

    def serialize(self, root):
        """Encodes a tree to a single string.

        :type root: TreeNode
        :rtype: str
        """
        # result to store the lsit
        res = []
        def dfs(node):
          # if None
            if not node:
              # append n to the res
                res.append("N")
                return
              # visit that node, append to the res
            res.append(str(node.val))
            # @ do the ame for left and right subtree
            dfs(node.left)
            dfs(node.right)
          # call dfs on root
        dfs(root)
        # join using comma as delimiter
        return ",".join(res)
        # @ output = [1,2,N,N,3,4,N,N,5,N,N]

    def deserialize(self, data):
        """Decodes your encoded data to tree.

        :type data: str
        :rtype: TreeNode
        """
        # make an array
        vals = data.split(",")
        # global variable to access the poiinter and setting to 0
        self.i = 0

        def dfs():
          # if the value encountred is N, then add None node
            if vals[self.i] == "N":
                self.i+=1
                return None
            # create a node with value at i
            node = TreeNode(int(vals[self.i]))
            # increment the i
            self.i+=1
            # build the left and right subtrees
            node.left = dfs()
            node.right = dfs()
            # return node
          # call dfs
        return dfs()



# Your Codec object will be instantiated and called as such:
# ser = Codec()
# deser = Codec()
# ans = deser.deserialize(ser.serialize(root))

# %%
# https://leetcode.com/problems/flatten-binary-tree-to-linked-list/description/
# 114. Flatten Binary Tree to Linked List



# Definition for a binary tree node.
# class TreeNode:
#     def __init__(self, val=0, left=None, right=None):
#         self.val = val
#         self.left = left
#         self.right = right
def flatten(self, root: Optional[TreeNode]) -> None:
        """
        Do not return anything, modify root in-place instead.
        """
        # flatten the root tree and return the list tail
        def dfs(root):
            if not root:
                return None
                # flatten the left and right subtree
            leftTail = dfs(root.left)
            rightTail = dfs(root.right)
            # we only do if we have the left tail
            # because we will be having the right subtree flattened
            if leftTail:
              # make the tail of the left flattened tree point to right
                leftTail.right = root.right
                # make the root right to root left
                root.right = root.left
                # make the left as none
                root.left = None
              # return first right flattened or then left flattened or the root if both empty
            return rightTail or leftTail or root

        dfs(root)


        if root==None:
            return None
        st=[root]
        while st:
            node=st.pop()
            if node.right:
                st.append(node.right)
            if node.left:
                st.append(node.left)
        # make right the last visited node
            if len(st)>0:
                node.right=st[-1]
            node.left=None


# o(n) o(logN)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-41ab3c5ee135> in <cell line: 7>()
#       5 #         self.left = left
#       6 #         self.right = right
# ----> 7 def flatten(self, root: Optional[TreeNode]) -> None:
#       8         """
#       9         Do not return anything, modify root in-place instead.
#
# NameError: name 'Optional' is not defined

# %%
# 236. Lowest Common Ancestor of a Binary Tree
# https://leetcode.com/problems/lowest-common-ancestor-of-a-binary-tree/description/


# Definition for a binary tree node.
# class TreeNode:
#     def __init__(self, x):
#         self.val = x
#         self.left = None
#         self.right = None

class Solution:
    def lowestCommonAncestor(self, root: 'TreeNode', p: 'TreeNode', q: 'TreeNode') -> 'TreeNode':
        # base case to check if not root
        if not root:
            return None
            # if root is equal to either of the p or q, return that roo to root
        if root == p or root == q:
            return root
        # get l and r from both the subtrees
        l = self.lowestCommonAncestor(root.left, p,q)
        r = self.lowestCommonAncestor(root.right, p,q)
        # if both the left and right return a value, that means pan q are on the opposite sided of the tree
        # so return that root
        if l and r:
            return root
        # else if one return null value, return l or r
        else:
            return l or r


        #o(n) o(1)

Input: root = [3,5,1,6,2,0,8,null,null,7,4], p = 5, q = 1
Output: 3

# %%
# https://leetcode.com/problems/binary-tree-paths/description/
# 257. Binary Tree Paths

# Definition for a binary tree node.
# class TreeNode:
#     def __init__(self, val=0, left=None, right=None):
#         self.val = val
#         self.left = left
#         self.right = right
class Solution:
    def binaryTreePaths(self, root: Optional[TreeNode]) -> List[str]:
        # take empty res
        ans = []
        # pass root and subpath
        def solve(root, s):
            # add to the path the value of the current node
            s += str(root.val)
            # if leaf node, then append the path to the result
            if not root.right and not root.left:
                ans.append(s)
                return
            # if right node, perform on right passing the current subpath
            if root.right:
                solve(root.right, s+"->")
            if root.left:
                solve(root.left, s+"->")

        # run dfs for root
        solve(root, "")
        return ans


root = [1,2,3,null,5]
Output: ["1->2->5","1->3"]

# %%
# https://leetcode.com/problems/convert-binary-search-tree-to-sorted-doubly-linked-list/description/
# 426. Convert Binary Search Tree to Sorted Doubly Linked List
# Medium

"""
# Definition for a Node.
class Node:
    def __init__(self, val, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right
"""
# basically this is inorder traversal
# visit left, root, right
class Solution:
    def treeToDoublyList(self, root: 'Optional[Node]') -> 'Optional[Node]':
        if not root:
            return None
        # keep the track of the first element in linked list
        self.first = None
        # every node we visit we make it as last
        self.last = None

        self.inorder_link(root)
        # to mkae it circular, we join the left of first to last
        self.first.left = self.last
        # make right of last to first
        self.last.right = self.first

        return self.first

    def inorder_link(self, node):
        if node:
            # reach the left end
            self.inorder_link(node.left)
            # we are at extremem ;eft where there is no node
            if not self.last:
                # this will be our first element
                self.first = node
                # now we got our first, we will link the current node left to last node we visited
            else:
                node.left = self.last
                # last nodes right iwill popint ot this node
                self.last.right = node

                # make the visited node as last everytime
            self.last = node

            # perform same on the right
            self.inorder_link(node.right)


                    # o(n) o(n)


Input: root = [4,2,5,1,3]


Output: [1,2,3,4,5]

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
for i in range(-2, 3):
  print(i)
# Out:
# -2
# -1
# 0
# 1
# 2

# %%
# https://leetcode.com/problems/binary-tree-vertical-order-traversal/description/
# 314. Binary Tree Vertical Order Traversal
#MEDIUM
from collections import defaultdict,deque
# Definition for a binary tree node.
class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right
class Solution:
    def verticalOrder(self, root: TreeNode):

        if not root:
            return []

        columns = defaultdict(list)

        q = deque([(root, 0)])
        while q:
            node, x = q.popleft()
            columns[x].append(node.val)

            if node.left:
                q.append((node.left, x - 1))
            if node.right:
                q.append((node.right, x + 1))

        return [columns[x] for x in range(min(columns), max(columns)+1)]



#o(n) o(n)
root = [3,9,20,null,null,15,7]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-6959bd76e9ac> in <cell line: 34>()
#      32
#      33
# ---> 34 root = [3,9,20,null,null,15,7]
#      35
#
# NameError: name 'null' is not defined

# %%
# https://leetcode.com/problems/vertical-order-traversal-of-a-binary-tree/solutions/2527209/easy-python-code-with-dfs-and-default-dictionary/
# 987. Vertical Order Traversal of a Binary Tree
# Hard

# Definition for a binary tree node.
# class TreeNode:
#     def __init__(self, val=0, left=None, right=None):
#         self.val = val
#         self.left = left
#         self.right = right
class Solution:
    def verticalTraversal(self, root: Optional[TreeNode]) -> List[List[int]]:
        ans = []
        def dfs(root,r,c):
            if root:
                ans.append([r,c,root.val])
                dfs(root.left,r+1,c-1)
                dfs(root.right,r+1,c+1)
            return
        dfs(root,0,0)
        ans=sorted(ans,key=lambda x:(x[1],x[0],x[2]))
        d=defaultdict(list)
        for i,j,k in ans:
            d[j].append(k)
        l=[]
        for i in d.values():
            l.append(i)
        return l

# %%
# when declreaing a variable, in t it instantizted by a class
# so int is a calss, str is a calss

# add self to method as pyhton passes the same object as first parameter

class Item:
  def calculate_total_price(self, x, y):
    return x*y


item1 = Item()
item1.name = "Phone"
item1.price = 100
item1.quantity = 5
print(item1.calculate_total_price(item1.price, item1.quantity))

item2 = Item()
item2.name = "Phone"
item2.price = 100
item2.quantity = 5
print(item2.calculate_total_price(item2.price, item2.quantity))

print(type(item1))
print(type(item1.name))
# Out:
# 500
# 500
# <class '__main__.Item'>
# <class 'str'>

# %%
# __init__ is contructor
# pass the parameters

class Item:
  def __init__(self) -> None:
    print("I AM CREATED")
  def calculate_total_price(self, x, y):
    return x*y


item1 = Item()
item1.name = "Phone"
item1.price = 100
item1.quantity = 5

item2 = Item()
item2.name = "Phone"
item2.price = 100
item2.quantity = 5
# Out:
# I AM CREATED
# I AM CREATED

# %%
# assign attributes
class Item:
  def __init__(self,name, price, quantity) -> None:
    print(f"I AM CREATED: {name}")
    self.name = name
    self.price = price
    self.quantity = quantity
  def calculate_total_price(self, x, y):
    return x*y


item1 = Item("Phone", 100,5)

item2 = Item("Laptop", 100, 5)


print(item1.name)
print(item2.name)
print(item2.quantity)
# Out:
# I AM CREATED: Phone
# I AM CREATED: Laptop
# Phone
# Laptop
# 5

# %%
# add default values to atributes
class Item:
  def __init__(self,name, price, quantity ) -> None:
    print(f"I AM CREATED: {name}")
    self.name = name
    self.price = price
    self.quantity = quantity
    # pass the initialized variables
  def calculate_total_price(self):
    return self.price*self.quantity


item1 = Item("Phone", 100,10)

item2 = Item("Laptop", 100, 5)
item2.has_numpad = False

print(item1.name)
print(item2.name)
print(item2.has_numpad)
print(item1.calculate_total_price())
print(item2.calculate_total_price())
# Out:
# I AM CREATED: Phone
# I AM CREATED: Laptop
# Phone
# Laptop
# False
# 1000
# 500

# %%
# validating the parameters that is beign passed
class Item:
  def __init__(self,name: str, price: float, quantity:int ) -> None:
    print(f"I AM CREATED: {name}")
    self.name = name
    self.price = price
    self.quantity = quantity
    # pass the initialized variables
  def calculate_total_price(self):
    return self.price*self.quantity


item1 = Item(1, 100,1)

item2 = Item("Laptop", 100, 5)
item2.has_numpad = False
# Out:
# I AM CREATED: 1
# I AM CREATED: Laptop

# %%
# add assertion to validate arguments


class Item:
    def __init__(self, name: str, price: float, quantity: int) -> None:

        assert quantity >= 0, f"Price {price} should be greater than zero"

        print(f"I AM CREATED: {name}")
        self.name = name
        self.price = price
        self.quantity = quantity
        # pass the initialized variables

    def calculate_total_price(self):
        return self.price*self.quantity


item1 = Item("Phone", 100, 1)

item2 = Item("Laptop", 100, 5)
item2.has_numpad = False
# Out:
# I AM CREATED: Phone
# I AM CREATED: Laptop

# %%
# instance level attribute
class Item:

    pay_rate = 0.8
    def __init__(self, name: str, price: float, quantity: int) -> None:

        assert quantity >= 0, f"Price {price} should be greater than zero"

        print(f"I AM CREATED: {name}")
        self.name = name
        self.price = price
        self.quantity = quantity
        # pass the initialized variables

    def calculate_total_price(self):
        return self.price*self.quantity


item1 = Item("Phone", 100, 1)

item2 = Item("Laptop", 100, 5)
item2.has_numpad = False


print(Item.pay_rate)
print(item2.pay_rate)

print(Item.__dict__)
print(item1.__dict__)
# Out:
# I AM CREATED: Phone
# I AM CREATED: Laptop
# 0.8
# 0.8
# {'__module__': '__main__', 'pay_rate': 0.8, '__init__': <function Item.__init__ at 0x7ef892c7bac0>, 'calculate_total_price': <function Item.calculate_total_price at 0x7ef892c79d80>, '__dict__': <attribute '__dict__' of 'Item' objects>, '__weakref__': <attribute '__weakref__' of 'Item' objects>, '__doc__': None}
# {'name': 'Phone', 'price': 100, 'quantity': 1}

# %%
# instance level attribute
class Item:

    pay_rate = 0.8
    def __init__(self, name: str, price: float, quantity: int) -> None:

        assert quantity >= 0, f"Price {price} should be greater than zero"

        print(f"I AM CREATED: {name}")
        self.name = name
        self.price = price
        self.quantity = quantity
        # pass the initialized variables

    def calculate_total_price(self):
        return self.price*self.quantity

    def apply_discount(self):
      # payrate is taken from class level
      # self.price = self.price * Item.pay_rate
      # payrate is taken from instance level
      self.price = self.price * self.pay_rate


item1 = Item("Phone", 100, 1)

item2 = Item("Laptop", 1000, 5)
item2.has_numpad = False
item2.pay_rate = 0.7

print(item1.apply_discount())
print(item1.price)

print(item2.apply_discount())
print(item2.price)
# Out:
# I AM CREATED: Phone
# I AM CREATED: Laptop
# None
# 80.0
# None
# 700.0

# %%
# get the list of all the instances v=created
class Item:

    pay_rate = 0.8
    # list to store instances
    all = []
    def __init__(self, name: str, price: float, quantity: int) -> None:
        # run validations
        assert quantity >= 0, f"Price {price} should be greater than zero"
        # assign to self object
        print(f"I AM CREATED: {name}")
        self.name = name
        self.price = price
        self.quantity = quantity


      # actions to execute
      # adding to the constructor when initialized
        Item.all.append(self)




    def calculate_total_price(self):
        return self.price*self.quantity

    def apply_discount(self):
      # payrate is taken from class level
      # self.price = self.price * Item.pay_rate
      # payrate is taken from instance level
      self.price = self.price * self.pay_rate


item1 = Item("Phone", 100, 1)
item2 = Item("Laptop", 1000, 3)
item3 = Item("Cable", 10, 5)
item4 = Item("Mouse", 50, 5)
item5 = Item("Keyboard", 75, 5)


print(Item.all)

for items in Item.all:
  print(items.name)
# Out:
# I AM CREATED: Phone
# I AM CREATED: Laptop
# I AM CREATED: Cable
# I AM CREATED: Mouse
# I AM CREATED: Keyboard
# [<__main__.Item object at 0x7ef892c510c0>, <__main__.Item object at 0x7ef8b728edd0>, <__main__.Item object at 0x7ef8b728e6b0>, <__main__.Item object at 0x7ef8b728d6c0>, <__main__.Item object at 0x7ef892c525f0>]
# Phone
# Laptop
# Cable
# Mouse
# Keyboard

# %%
# __repr__
class Item:

    pay_rate = 0.8
    # list to store instances
    all = []
    def __init__(self, name: str, price: float, quantity: int) -> None:
        # run validations
        assert quantity >= 0, f"Price {price} should be greater than zero"
        # assign to self object
        print(f"I AM CREATED: {name}")
        self.name = name
        self.price = price
        self.quantity = quantity


      # actions to execute
      # adding to the constructor when initialized
        Item.all.append(self)




    def calculate_total_price(self):
        return self.price*self.quantity

    def apply_discount(self):
      # payrate is taken from class level
      # self.price = self.price * Item.pay_rate
      # payrate is taken from instance level
      self.price = self.price * self.pay_rate
    # represent the instances in the format

    def __repr__(self) -> str:
       return f"('{self.name}', {self.price}, {self.quantity})"


item1 = Item("Phone", 100, 1)
item2 = Item("Laptop", 1000, 3)
item3 = Item("Cable", 10, 5)
item4 = Item("Mouse", 50, 5)
item5 = Item("Keyboard", 75, 5)


print(Item.all)

for items in Item.all:
  print(items.name)
# Out:
# I AM CREATED: Phone
# I AM CREATED: Laptop
# I AM CREATED: Cable
# I AM CREATED: Mouse
# I AM CREATED: Keyboard
# [('Phone', 100, 1), ('Laptop', 1000, 3), ('Cable', 10, 5), ('Mouse', 50, 5), ('Keyboard', 75, 5)]
# Phone
# Laptop
# Cable
# Mouse
# Keyboard

# %%
# accessing the csv file
# clamm methods
import csv

class Item:

    pay_rate = 0.8
    # list to store instances
    all = []
    def __init__(self, name: str, price: float, quantity: int) -> None:
        # run validations
        assert quantity >= 0, f"Price {price} should be greater than zero"
        # assign to self object
        print(f"I AM CREATED: {name}")
        self.name = name
        self.price = price
        self.quantity = quantity


      # actions to execute
      # adding to the constructor when initialized
        Item.all.append(self)




    def calculate_total_price(self):
        return self.price*self.quantity

    def apply_discount(self):
      # payrate is taken from class level
      # self.price = self.price * Item.pay_rate
      # payrate is taken from instance level
      self.price = self.price * self.pay_rate
    # represent the instances in the format


    @classmethod
    def instantiate_from_csv(cls):
      with open('items.csv', 'r') as f:
        reader = csv.DictReader(f)
        items = list(reader)

        for item in items:
          Item(
              name=item.get('name'),
              price = float(item.get('price')),
              quantity = int(item.get('quantity'))
          )


    # representing the instances in a format
    def __repr__(self) -> str:
       return f"('{self.name}', {self.price}, {self.quantity})"


Item.instantiate_from_csv()
print(Item.all)
# Out:
# I AM CREATED: Phone
# I AM CREATED: Laptop
# I AM CREATED: Cable
# I AM CREATED: Mouse
# I AM CREATED: Keyboard
# [('Phone', 100.0, 1), ('Laptop', 1000.0, 3), ('Cable', 10.0, 5), ('Mouse', 50.0, 5), ('Keyboard', 75.0, 5)]

# %%
# static  methods
import csv

class Item:

    pay_rate = 0.8
    # list to store instances
    all = []
    def __init__(self, name: str, price: float, quantity: int) -> None:
        # run validations
        assert quantity >= 0, f"Price {price} should be greater than zero"
        # assign to self object
        print(f"I AM CREATED: {name}")
        self.name = name
        self.price = price
        self.quantity = quantity


      # actions to execute
      # adding to the constructor when initialized
        Item.all.append(self)




    def calculate_total_price(self):
        return self.price*self.quantity

    def apply_discount(self):
      # payrate is taken from class level
      # self.price = self.price * Item.pay_rate
      # payrate is taken from instance level
      self.price = self.price * self.pay_rate
    # represent the instances in the format


    @classmethod
    def instantiate_from_csv(cls):
      with open('items.csv', 'r') as f:
        reader = csv.DictReader(f)
        items = list(reader)

        for item in items:
          Item(
              name=item.get('name'),
              price = float(item.get('price')),
              quantity = int(item.get('quantity'))
          )


    # in static method, we do not pas instance or calss as the first argument
    @staticmethod
    def is_integer(num):
    # 10.0 5.0
      if isinstance(num, float):
        return num.is_integer()
      elif isinstance(num, int):
        return True
      else:
        return False

    # representing the instances in a format
    def __repr__(self) -> str:
       return f"('{self.name}', {self.price}, {self.quantity})"


print(Item.is_integer(15.0))

print(Item.is_integer(15.5))
# Out:
# True
# False

# %%
# STATIC method when we do not have that mehtod to be unique per Instance

# CLASS method is used to manipulate different data structures of data to in
#  to instattiate objects like we did with the csv


# difference is that static method does not pass instance as the forst argument in the background

# do not call static or class mehtod from instance level, call it from class level

# %%
# INHERITENCE
# parents and child



import csv

class Item:

    pay_rate = 0.8
    # list to store instances
    all = []
    def __init__(self, name: str, price: float, quantity: int) -> None:
        # run validations
        assert quantity >= 0, f"Price {price} should be greater than zero"
        # assign to self object
        print(f"I AM CREATED: {name}")
        self.name = name
        self.price = price
        self.quantity = quantity


      # actions to execute
      # adding to the constructor when initialized
        Item.all.append(self)




    def calculate_total_price(self):
        return self.price*self.quantity

    def apply_discount(self):
      # payrate is taken from class level
      # self.price = self.price * Item.pay_rate
      # payrate is taken from instance level
      self.price = self.price * self.pay_rate
    # represent the instances in the format


    @classmethod
    def instantiate_from_csv(cls):
      with open('items.csv', 'r') as f:
        reader = csv.DictReader(f)
        items = list(reader)

        for item in items:
          Item(
              name=item.get('name'),
              price = float(item.get('price')),
              quantity = int(item.get('quantity'))
          )


    # in static method, we do not pas instance or calss as the first argument
    @staticmethod
    def is_integer(num):
    # 10.0 5.0
      if isinstance(num, float):
        return num.is_integer()
      elif isinstance(num, int):
        return True
      else:
        return False

    # representing the instances in a format
    def __repr__(self) -> str:
       return f"('{self.name}', {self.price}, {self.quantity})"

#-------------------------------------------------
class Phone(Item):
  # use
  all= []
  def __init__(self, name: str, price: float, quantity: int, broken_phones = 0) -> None:
        # call to super function to have access to all attriubutes/ methods
        super().__init__(
            name, price, quantity
        )
        # run validations
        assert broken_phones >= 0, f"Price {broken_phones} should be greater than zero"
        # assign to self object
        self.broken_phones = broken_phones


      # actions to execute
      # adding to the constructor when initialized
        Phone.all.append(self)







phone1 = Phone("jsPhone10", 500, 5, 1)
print(phone1.calculate_total_price())
phone2 = Phone("jsPhone20", 700, 5, 1)
# Out:
# I AM CREATED: jsPhone10
# 2500
# I AM CREATED: jsPhone20

# %%
# return class name instantiating it
# only use the __repr__ to parent class to get the list of all the files
# item.py
import csv

class Item:

    pay_rate = 0.8
    # list to store instances
    all = []
    def __init__(self, name: str, price: float, quantity: int) -> None:
        # run validations
        assert quantity >= 0, f"Price {price} should be greater than zero"
        # assign to self object
        print(f"I AM CREATED: {name}")
        self.name = name
        self.price = price
        self.quantity = quantity


      # actions to execute
      # adding to the constructor when initialized
        Item.all.append(self)




    def calculate_total_price(self):
        return self.price*self.quantity

    def apply_discount(self):
      # payrate is taken from class level
      # self.price = self.price * Item.pay_rate
      # payrate is taken from instance level
      self.price = self.price * self.pay_rate
    # represent the instances in the format


    @classmethod
    def instantiate_from_csv(cls):
      with open('items.csv', 'r') as f:
        reader = csv.DictReader(f)
        items = list(reader)

        for item in items:
          Item(
              name=item.get('name'),
              price = float(item.get('price')),
              quantity = int(item.get('quantity'))
          )


    # in static method, we do not pas instance or calss as the first argument
    @staticmethod
    def is_integer(num):
    # 10.0 5.0
      if isinstance(num, float):
        return num.is_integer()
      elif isinstance(num, int):
        return True
      else:
        return False

    # representing the instances in a format
    def __repr__(self) -> str:

      # change here to have the class name printed
      #  return f"(Items('{self.name}', {self.price}, {self.quantity})"
       return f"({self.__class__.__name__}('{self.name}', {self.price}, {self.quantity})"

# phone.py
#-------------------------------------------------
class Phone(Item):
  # use
  def __init__(self, name: str, price: float, quantity: int, broken_phones = 0) -> None:
        # call to super function to have access to all attriubutes/ methods
        super().__init__(
            name, price, quantity
        )
        # run validations
        assert broken_phones >= 0, f"Price {broken_phones} should be greater than zero"
        # assign to self object
        self.broken_phones = broken_phones



phone1 = Phone("jsPhone10", 500, 5, 1)

print(Item.all)

# importing the files to get the class
# main.py
from item import Item
from phone import Phone


Item.instantiate_from_csv()

print(Item.all)
# Out:
# I AM CREATED: jsPhone10
# [(Phone('jsPhone10', 500, 5)]

# %%
# items.py
import csv


class Item:

    pay_rate = 0.8
    # list to store instances
    all = []

    def __init__(self, name: str, price: float, quantity: int) -> None:
        # run validations
        assert quantity >= 0, f"Price {price} should be greater than zero"
        # assign to self object
        print(f"I AM CREATED: {name}")
        self.name = name
        self.price = price
        self.quantity = quantity

      # actions to execute
      # adding to the constructor when initialized
        Item.all.append(self)

    def calculate_total_price(self):
        return self.price*self.quantity

    def apply_discount(self):
      # payrate is taken from class level
      # self.price = self.price * Item.pay_rate
      # payrate is taken from instance level
        self.price = self.price * self.pay_rate
    # represent the instances in the format

    @classmethod
    def instantiate_from_csv(cls):
        with open('items.csv', 'r') as f:
            reader = csv.DictReader(f)
            items = list(reader)

            for item in items:
                Item(
                    name=item.get('name'),
                    price=float(item.get('price')),
                    quantity=int(item.get('quantity'))
                )

    # in static method, we do not pas instance or calss as the first argument

    @staticmethod
    def is_integer(num):
        # 10.0 5.0
        if isinstance(num, float):
            return num.is_integer()
        elif isinstance(num, int):
            return True
        else:
            return False

    # representing the instances in a format
    def __repr__(self) -> str:

        # change here to have the class name printed
        #  return f"(Items('{self.name}', {self.price}, {self.quantity})"
        return f"({self.__class__.__name__}('{self.name}', {self.price}, {self.quantity})"



      # property tag to set the read only value
    @property
    def read_only_names(self):
        return "AAA"


# main.py
from item import Item
from phone import Phone


item1 = Item("Phone", 100, 2)
item1.name = "Name changes"
item1.read_only_names = "bbb"
print(item1.read_only_names)

# %%
# ENCAPSULATION to hide data from customers
# make variables it just read only


#  items.py


import csv


class Item:

    pay_rate = 0.8
    # list to store instances
    all = []

    def __init__(self, name: str, price: float, quantity: int) -> None:
        # run validations
        assert quantity >= 0, f"Price {price} should be greater than zero"
        # assign to self object
        print(f"I AM CREATED: {name}")
        # add single underscore for the variable, but _name can be accessed
        # to avoid this, use double underswcore, theis makes it private
        self.__name = name
        self.price = price
        self.quantity = quantity

      # actions to execute
      # adding to the constructor when initialized
        Item.all.append(self)



    # encapsulation
    # getter
    @property  # read only property attribute
    def name(self):
        return self.__name

    # setter
    # if the user wants to set the property of a read only value
    @name.setter
    def name(self, value):
        if len(value) > 10:
            raise Exception("The name is too long!!")
        else:
            self.__name = value

    def calculate_total_price(self):
        return self.price*self.quantity
import csv


class Item:

    pay_rate = 0.8
    # list to store instances
    all = []

    def __init__(self, name: str, price: float, quantity: int) -> None:
        # run validations
        assert quantity >= 0, f"Price {price} should be greater than zero"
        # assign to self object
        print(f"I AM CREATED: {name}")
        # add single underscore for the variable, but _name can be accessed
        # to avoid this, use double underswcore, theis makes it private
        self.__name = name
        self.__price = price
        self.quantity = quantity

      # actions to execute
      # adding to the constructor when initialized
        Item.all.append(self)

    # encapsulation
    # getter

    @property  # read only property attribute
    def name(self):
        return self.__name

    # setter
    # if the user wants to set the property of a read only value
    @name.setter
    def name(self, value):
        if len(value) > 10:
            raise Exception("The name is too long!!")
        else:
            self.__name = value

    @property
    def price(self):
        return self.__price

    def apply_discount(self):
      # payrate is taken from class level
      # self.price = self.price * Item.pay_rate
      # payrate is taken from instance level
        self.__price = self.__price * self.pay_rate

    def apply_increment(self, inc_value):
        self.__price = self.__price + (self.__price*inc_value)

    def calculate_total_price(self):
        return self.price*self.quantity

    # represent the instances in the format

    @classmethod
    def instantiate_from_csv(cls):
        with open('items.csv', 'r') as f:
            reader = csv.DictReader(f)
            items = list(reader)

            for item in items:
                Item(
                    name=item.get('name'),
                    price=float(item.get('price')),
                    quantity=int(item.get('quantity'))
                )

    # in static method, we do not pas instance or calss as the first argument

    @staticmethod
    def is_integer(num):
        # 10.0 5.0
        if isinstance(num, float):
            return num.is_integer()
        elif isinstance(num, int):
            return True
        else:
            return False

    # representing the instances in a format
    def __repr__(self) -> str:

        # change here to have the class name printed
        #  return f"(Items('{self.name}', {self.price}, {self.quantity})"
        return f"({self.__class__.__name__}('{self.name}', {self.price}, {self.quantity})"

    def apply_discount(self):
      # payrate is taken from class level
      # self.price = self.price * Item.pay_rate
      # payrate is taken from instance level
        self.price = self.price * self.pay_rate
    # represent the instances in the format

    @classmethod
    def instantiate_from_csv(cls):
        with open('items.csv', 'r') as f:
            reader = csv.DictReader(f)
            items = list(reader)

            for item in items:
                Item(
                    name=item.get('name'),
                    price=float(item.get('price')),
                    quantity=int(item.get('quantity'))
                )

    # in static method, we do not pas instance or calss as the first argument

    @staticmethod
    def is_integer(num):
        # 10.0 5.0
        if isinstance(num, float):
            return num.is_integer()
        elif isinstance(num, int):
            return True
        else:
            return False

    # representing the instances in a format
    def __repr__(self) -> str:

        # change here to have the class name printed
        #  return f"(Items('{self.name}', {self.price}, {self.quantity})"
        return f"({self.__class__.__name__}('{self.name}', {self.price}, {self.quantity})"



#main.py

from item import Item
from phone import Phone


item1 = Item("Phone", 100, 2)
print(item1.name)
item1.apply_increment(0.2)
item1.apply_discount()
print(item1.price)

# %%
# ABSTRACTION
# make methods private
import csv


class Item:

    pay_rate = 0.8
    # list to store instances
    all = []

    def __init__(self, name: str, price: float, quantity: int) -> None:
        # run validations
        assert quantity >= 0, f"Price {price} should be greater than zero"
        # assign to self object
        print(f"I AM CREATED: {name}")
        # add single underscore for the variable, but _name can be accessed
        # to avoid this, use double underswcore, theis makes it private
        self.__name = name
        self.__price = price
        self.quantity = quantity

      # actions to execute
      # adding to the constructor when initialized
        Item.all.append(self)

    # encapsulation
    # getter

    @property  # read only property attribute
    def name(self):
        return self.__name

    # setter
    # if the user wants to set the property of a read only value
    @name.setter
    def name(self, value):
        if len(value) > 10:
            raise Exception("The name is too long!!")
        else:
            self.__name = value

    @property
    def price(self):
        return self.__price

    def apply_discount(self):
      # payrate is taken from class level
      # self.price = self.price * Item.pay_rate
      # payrate is taken from instance level
        self.__price = self.__price * self.pay_rate

    def apply_increment(self, inc_value):
        self.__price = self.__price + (self.__price*inc_value)

    def calculate_total_price(self):
        return self.price*self.quantity

    # represent the instances in the format

    @classmethod
    def instantiate_from_csv(cls):
        with open('items.csv', 'r') as f:
            reader = csv.DictReader(f)
            items = list(reader)

            for item in items:
                Item(
                    name=item.get('name'),
                    price=float(item.get('price')),
                    quantity=int(item.get('quantity'))
                )

    # in static method, we do not pas instance or calss as the first argument

    @staticmethod
    def is_integer(num):
        # 10.0 5.0
        if isinstance(num, float):
            return num.is_integer()
        elif isinstance(num, int):
            return True
        else:
            return False

    # representing the instances in a format
    def __repr__(self) -> str:

        # change here to have the class name printed
        #  return f"(Items('{self.name}', {self.price}, {self.quantity})"
        return f"({self.__class__.__name__}('{self.name}', {self.price}, {self.quantity})"

    def __connect(self, smpt_server):
        pass

    def __prepare_body(self):
        print(f" sent")
# making private

    def send_email(self):
        self.__connect("")
        self.__prepare_body()


from item import Item
from phone import Phone


item1 = Item("Phone", 100, 2)
print(item1.name)
item1.send_email()

# %%
# POLYMORPHIsm
# len built in function knows how to handle different kind of options
